# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLO11 Object Detection on a Custom Dataset
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# YOLO11 builds on the advancements introduced in YOLOv9 and YOLOv10 earlier this year, incorporating improved architectural designs, enhanced feature extraction techniques, and optimized training methods.
#
# YOLO11m achieves a higher mean mAP score on the COCO dataset while using 22% fewer parameters than YOLOv8m, making it computationally lighter without sacrificing performance.
#
# YOLOv11 is available in 5 different sizes, ranging from `2.6M` to `56.9M` parameters, and capable of achieving from `39.5` to `54.7` mAP on the COCO dataset.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Nov 21 00:43:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/112.6 GB disk)

# %% [markdown]
# ## Inference with model pre-trained on COCO dataset

# %% [markdown]
# ### CLI
#
# **NOTE:** CLI requires no customization or Python code. You can simply run all tasks from the terminal with the yolo command.

# %%
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 45.3ms
# Speed: 2.2ms preprocess, 45.3ms inference, 64.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Result annotated image got saved in `{HOME}/runs/detect/predict/`. Let's display it.

# %%
import glob
import os
from IPython.display import Image as IPyImage

# Dynamically find the latest prediction folder
latest_folder = max(glob.glob(f'{HOME}/runs/detect/predict*/'), key=os.path.getmtime)

# Try to find the image with common extensions
image_path = None
for ext in ['.jpeg', '.jpg', '.png']:
    potential_path = os.path.join(latest_folder, f'dog{ext}')
    if os.path.exists(potential_path):
        image_path = potential_path
        break

if image_path:
    IPyImage(filename=image_path, width=600)
else:
    print(f"Error: Could not find 'dog' image with common extensions in '{latest_folder}'.")
    print(f"Contents of {latest_folder}: {os.listdir(latest_folder)}")

# %% [markdown]
# ### SDK
#
# **NOTE:** YOLO's Python interface allows for seamless integration into your Python projects, making it easy to load, run, and process the model's output.

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# 0: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# **NOTE:** The obtained `result` object stores information about the location, classes, and confidence levels of the detected objects.

# %%
result.boxes.xyxy
# Out:
# tensor([[3.0705e+02, 6.4341e+02, 5.2919e+02, 1.2558e+03],
#         [6.1400e+01, 2.4994e+02, 6.5165e+02, 9.7412e+02],
#         [1.7803e+00, 3.5551e+02, 6.3404e+02, 1.2788e+03],
#         [1.1933e+00, 3.5620e+02, 3.8455e+02, 1.2776e+03],
#         [6.2615e+02, 7.1818e+02, 6.9975e+02, 7.8754e+02]], device='cuda:0')

# %%
result.boxes.conf
# Out:
# tensor([0.6832, 0.6284, 0.5941, 0.3923, 0.3875], device='cuda:0')

# %%
result.boxes.cls
# Out:
# tensor([26., 16.,  0.,  0.,  2.], device='cuda:0')

# %% [markdown]
# **NOTE:** YOLO11 can be easily integrated with `supervision` using the familiar `from_ultralytics` connector.

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# ## Fine-tune YOLO11 on custom dataset

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

workspace = rf.workspace("liangdianzhong")
project = workspace.project("-qvdww")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in 两点钟模型-3 to yolov11:: 100%|██████████| 22514/22514 [00:02<00:00, 8210.61it/s]
# Extracting Dataset Version Zip to 两点钟模型-3 in yolov11:: 100%|██████████| 2612/2612 [00:00<00:00, 6486.45it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.3.229 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11s.pt, data=/content/datasets/两点钟模型-3/data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763686694.688535    4529 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763686694.694598    4529 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763686694.716738    4529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763686694.716766    4529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763686694.716772    4529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763686694.716775    4529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Overriding model.yaml nc=80 with nc=23
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    828309  ultralytics.nn.modules.head.Detect           [23, [128, 256, 512]]
# YOLO11s summary: 319 layers, 9,436,693 parameters, 9,436,677 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/datasets/两点钟模型-3/train/labels.cache... 911 images, 0 backgrounds, 0 corrupt: 100% 911/911 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 23, len(boxes) = 16335. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/两点钟模型-3/valid/labels.cache... 259 images, 0 backgrounds, 0 corrupt: 100% 259/259 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/datasets/两点钟模型-3/valid/images/08_21C_0250_jpg.rf.b164fca68a7a644a126019aa776912c1.jpg: 2 duplicate labels removed
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00037, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 10 epochs...
# Closing dataloader mosaic
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      4.54G      1.454      2.851      0.911        254        640: 100% 57/57 [00:37<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:07<00:00,  1.19it/s]
#                    all        259       4652      0.583      0.717       0.68      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      4.52G      1.191      1.061     0.8581        226        640: 100% 57/57 [00:16<00:00,  3.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.12it/s]
#                    all        259       4652      0.828      0.864      0.885       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      4.53G      1.153     0.7935     0.8518        218        640: 100% 57/57 [00:16<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.99it/s]
#                    all        259       4652      0.905      0.891      0.953      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      4.52G      1.102     0.6787     0.8454        272        640: 100% 57/57 [00:16<00:00,  3.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.31it/s]
#                    all        259       4652      0.941      0.941      0.977      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.51G      1.051     0.6161      0.838        209        640: 100% 57/57 [00:16<00:00,  3.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  4.06it/s]
#                    all        259       4652      0.975      0.958      0.988      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.53G       1.01     0.5727      0.832        230        640: 100% 57/57 [00:16<00:00,  3.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.25it/s]
#                    all        259       4652      0.978      0.969       0.99      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      4.52G     0.9715     0.5369     0.8274        232        640: 100% 57/57 [00:16<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  4.01it/s]
#                    all        259       4652       0.98       0.97       0.99      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      4.46G     0.9349     0.5041     0.8229        229        640: 100% 57/57 [00:16<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.25it/s]
#                    all        259       4652      0.978      0.974       0.99      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      4.53G     0.9031     0.4916       0.82        243        640: 100% 57/57 [00:16<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.97it/s]
#                    all        259       4652      0.984      0.976       0.99       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      4.53G     0.8724     0.4728     0.8182        240        640: 100% 57/57 [00:16<00:00,  3.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.32it/s]
#                    all        259       4652      0.987      0.981      0.991      0.746
#
# 10 epochs completed in 0.062 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 19.2MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 19.2MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,421,701 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:05<00:00,  1.71it/s]
#                    all        259       4652      0.987      0.981      0.991      0.746
#                   bag1        258        258      0.996          1      0.995      0.757
#                   bag2        257        257      0.998          1      0.995      0.896
#                   bag3        250        250          1      0.973      0.995      0.805
#                   bag4        258        258      0.997          1      0.995      0.809
#                   bag5        258        258      0.997      0.996      0.995       0.91
#                   bag6        259        259      0.998          1      0.995      0.796
#                  ball0        250        250      0.985      0.984      0.992      0.727
#                  ball1        216        216      0.993      0.995      0.995      0.689
#                 ball10        248        248      0.996      0.984      0.995      0.717
#                 ball11        247        247      0.972      0.992      0.993      0.718
#                 ball12        248        249      0.985      0.964      0.989      0.712
#                 ball13        149        149      0.986      0.957      0.991      0.661
#                 ball14        155        157      0.943      0.962      0.965      0.728
#                 ball15        161        161      0.948      0.957      0.982      0.736
#                  ball2        219        220      0.991      0.985      0.987        0.7
#                  ball3        167        167      0.995      0.994      0.995      0.666
#                  ball4        159        159      0.996      0.981      0.994       0.75
#                  ball5        192        192          1      0.998      0.995      0.732
#                  ball6        129        129      0.977       0.97      0.992        0.7
#                  ball7        187        187      0.991      0.984      0.995       0.71
#                  ball8        251        254      0.992      0.988      0.993      0.727
#                  ball9        127        127      0.983      0.924      0.988      0.774
# Speed: 0.3ms preprocess, 3.4ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml  weights

# %%
import glob
import os
from IPython.display import Image as IPyImage

# Dynamically find the latest training folder
latest_train_folder = max(glob.glob(f'{HOME}/runs/detect/train*/'), key=os.path.getmtime)

IPyImage(filename=f'{latest_train_folder}/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

# Assuming latest_train_folder is defined in a preceding cell
# If not, you might need to re-run the cell that defines it, or define it here:
import glob, os
HOME = os.getcwd()
latest_train_folder = max(glob.glob(f'{HOME}/runs/detect/train*/'), key=os.path.getmtime)

IPyImage(filename=f'{latest_train_folder}/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

# Ensure latest_train_folder is defined. It's defined in preceding cells, but re-defining here for robustness.
import glob, os
HOME = os.getcwd()
latest_train_folder = max(glob.glob(f'{HOME}/runs/detect/train*/'), key=os.path.getmtime)

IPyImage(filename=f'{latest_train_folder}/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate fine-tuned model

# %%
import glob, os
HOME = os.getcwd()
latest_train_folder = max(glob.glob(f'{HOME}/runs/detect/train*/'), key=os.path.getmtime)

# !yolo task=detect mode=val model={latest_train_folder}/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,421,701 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/两点钟模型-3/valid/labels.cache... 259 images, 0 backgrounds, 0 corrupt: 100% 259/259 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/datasets/两点钟模型-3/valid/images/08_21C_0250_jpg.rf.b164fca68a7a644a126019aa776912c1.jpg: 2 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 17/17 [00:04<00:00,  3.43it/s]
#                    all        259       4652      0.987      0.981      0.991       0.75
#                   bag1        258        258      0.996          1      0.995      0.756
#                   bag2        257        257      0.998          1      0.995      0.896
#                   bag3        250        250          1      0.973      0.995      0.813
#                   bag4        258        258      0.997          1      0.995      0.805
#                   bag5        258        258      0.997      0.996      0.995        0.9
#                   bag6        259        259      0.998          1      0.995      0.819
#                  ball0        250        250      0.985      0.984      0.992      0.728
#                  ball1        216        216      0.993      0.995      0.995      0.688
#                 ball10        248        248      0.996      0.983      0.995      0.717
#                 ball11        247        247      0.972      0.992      0.993      0.722
#                 ball12        248        249      0.985      0.964      0.989      0.711
#                 ball13        149        149      0.986      0.957      0.991      0.681
#                 ball14        155        157      0.944      0.961      0.965      0.734
#                 ball15        161        161      0.948      0.957      0.982      0.746
#                  ball2        219        220      0.991      0.985      0.987      0.698
#                  ball3        167        167      0.995      0.994      0.995      0.666
#                  ball4        159        159      0.996      0.981      0.994      0.752
#                  ball5        192        192          1      0.997      0.995      0.733
#                  ball6        129        129      0.977       0.97      0.992      0.704
#                  ball7        187        187      0.991      0.984      0.995       0.73
#                  ball8        251        254      0.992      0.988      0.993      0.726
#                  ball9        127        127      0.983      0.924      0.988      0.776
# Speed: 0.7ms preprocess, 5.3ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 943, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 145, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 288, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 910, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 837, in torch_safe_load
#     ckpt = torch.load(file, map_location="cpu")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/patches.py", line 86, in torch_load
#     return _torch_load(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1484, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 740, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/train/weights/best.pt'

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob(f'{HOME}/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv11 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv11 weights.

# %%
# !pip install --upgrade roboflow
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{latest_train_folder}")
# Out:
# An error occured when getting the model upload URL: 404 Client Error: Not Found for url: https://api.roboflow.com/liangdianzhong/-qvdww/3/uploadModel?api_key=6kRa9E1Byk60qrjBXpZW&modelType=yolov11&nocache=true

# %%
# !pip install inference
# Out:
# Collecting inference
#   Downloading inference-0.62.0-py3-none-any.whl.metadata (24 kB)
# Collecting aiortc>=1.9.0 (from inference)
#   Downloading aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting APScheduler<4.0.0,>=3.10.1 (from inference)
#   Downloading apscheduler-3.11.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting asyncua~=1.1.5 (from inference)
#   Downloading asyncua-1.1.8-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: cachetools<6.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (5.5.2)
# Requirement already satisfied: cython~=3.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (3.0.12)
# Collecting python-dotenv~=1.0.0 (from inference)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting fastapi<0.116,>=0.100 (from inference)
#   Downloading fastapi-0.115.14-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy<2.3.5,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (2.0.2)
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opencv-contrib-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow<12.0,>=11.0 in /usr/local/lib/python3.12/dist-packages (from inference) (11.3.0)
# Collecting prometheus-fastapi-instrumentator<=6.0.0 (from inference)
#   Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting psutil>=7.0.0 (from inference)
#   Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting redis~=5.0.0 (from inference)
#   Downloading redis-5.0.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from inference) (2.32.4)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (13.9.4)
# Requirement already satisfied: supervision>=0.27 in /usr/local/lib/python3.12/dist-packages (from inference) (0.27.0)
# Collecting pybase64~=1.0.0 (from inference)
#   Downloading pybase64-1.0.2.tar.gz (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-image<=0.25.2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from inference) (0.25.2)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (1.0.0)
# Requirement already satisfied: wheel<=0.45.1,>=0.38.1 in /usr/local/lib/python3.12/dist-packages (from inference) (0.45.1)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (75.2.0)
# Requirement already satisfied: networkx<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (3.5)
# Requirement already satisfied: pydantic<2.12.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from inference) (2.11.10)
# Collecting pydantic-settings<2.8 (from inference)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: openai<2.0.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from inference) (1.109.1)
# Collecting structlog<25.0.0,>=24.1.0 (from inference)
#   Downloading structlog-24.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting zxing-cpp~=2.2.0 (from inference)
#   Downloading zxing_cpp-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting boto3<=1.35.60 (from inference)
#   Downloading boto3-1.35.60-py3-none-any.whl.metadata (6.7 kB)
# Collecting typing_extensions<=4.12.2,>=4.8.0 (from inference)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydot~=2.0.0 (from inference)
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting shapely<2.1.0,>=2.0.4 (from inference)
#   Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting tldextract~=5.1.2 (from inference)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting packaging~=24.0 (from inference)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting anthropic~=0.49.0 (from inference)
#   Downloading anthropic-0.49.0-py3-none-any.whl.metadata (24 kB)
# Collecting pandas<3.0.0,>=2.2.3 (from inference)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 11.0 MB/s eta 0:00:00
# Collecting paho-mqtt~=1.6.1 (from inference)
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (8.4.2)
# Requirement already satisfied: tokenizers<0.23.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from inference) (0.22.1)
# Collecting slack-sdk~=3.33.4 (from inference)
#   Downloading slack_sdk-3.33.5-py2.py3-none-any.whl.metadata (15 kB)
# Collecting twilio~=9.3.7 (from inference)
#   Downloading twilio-9.3.8-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: httpx~=0.28.1 in /usr/local/lib/python3.12/dist-packages (from inference) (0.28.1)
# Collecting pylogix==1.0.5 (from inference)
#   Downloading pylogix-1.0.5-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting pymodbus<=3.8.3,>=3.6.9 (from inference)
#   Downloading pymodbus-3.8.3-py3-none-any.whl.metadata (15 kB)
# Collecting backoff~=2.2.0 (from inference)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting filelock<=3.17.0,>=3.12.0 (from inference)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting onvif-zeep-async==2.0.0 (from inference)
#   Downloading onvif_zeep_async-2.0.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting simple-pid~=2.0.1 (from inference)
#   Downloading simple_pid-2.0.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting qrcode~=8.0.0 (from inference)
#   Downloading qrcode-8.0-py3-none-any.whl.metadata (17 kB)
# Collecting inference-exp>=0.15.2 (from inference)
#   Downloading inference_exp-0.16.3-py3-none-any.whl.metadata (20 kB)
# Collecting onnxruntime<1.22.0,>=1.15.1 (from inference)
#   Downloading onnxruntime-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Collecting nvidia-ml-py<13.0.0 (from inference)
#   Downloading nvidia_ml_py-12.575.51-py3-none-any.whl.metadata (9.3 kB)
# Collecting docker<8.0.0,>=7.0.0 (from inference)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting click<8.2.0 (from inference)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting typer<=0.16.0,>=0.9.0 (from inference)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML~=6.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (6.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (4.67.1)
# Requirement already satisfied: py-cpuinfo~=9.0.0 in /usr/local/lib/python3.12/dist-packages (from inference) (9.0.0)
# Collecting aiohttp<=3.10.11,>=3.9.0 (from inference)
#   Downloading aiohttp-3.10.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting dataclasses-json~=0.6.0 (from inference)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting zeep<5.0.0,>=4.2.1 (from zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference)
#   Downloading zeep-4.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.22.0)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->inference)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<17.0.0,>=14.0.0 (from aiortc>=1.9.0->inference)
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->inference)
#   Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.12/dist-packages (from aiortc>=1.9.0->inference) (1.7.1)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->inference)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->inference)
#   Downloading pylibsrtp-1.0.0-cp310-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->inference)
#   Downloading pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic~=0.49.0->inference) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic~=0.49.0->inference) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic~=0.49.0->inference) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic~=0.49.0->inference) (1.3.1)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.12/dist-packages (from APScheduler<4.0.0,>=3.10.1->inference) (5.3.1)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from asyncua~=1.1.5->inference) (24.1.0)
# Collecting aiosqlite (from asyncua~=1.1.5->inference)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from asyncua~=1.1.5->inference) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from asyncua~=1.1.5->inference) (2025.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from asyncua~=1.1.5->inference) (2.4.0)
# Collecting botocore<1.36.0,>=1.35.60 (from boto3<=1.35.60->inference)
#   Downloading botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<=1.35.60->inference)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<=1.35.60->inference)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8.0.0,>=7.0.0->inference) (2.5.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<0.116,>=0.100->inference)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx~=0.28.1->inference) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx~=0.28.1->inference) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx~=0.28.1->inference) (3.7)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx~=0.28.1->inference) (0.16.0)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (0.23.0+cu126)
# Requirement already satisfied: transformers<5.0.0,>=4.56.0 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (4.57.1)
# Requirement already satisfied: timm<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (1.0.22)
# Requirement already satisfied: accelerate<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (1.11.0)
# Requirement already satisfied: einops<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (0.8.1)
# Requirement already satisfied: peft<0.18.0,>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from inference-exp>=0.15.2->inference) (0.17.1)
# Collecting num2words~=0.5.14 (from inference-exp>=0.15.2->inference)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting bitsandbytes<0.48.0,>=0.42.0 (from inference-exp>=0.15.2->inference)
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Collecting pyvips<3.0.0,>=2.2.3 (from inference-exp>=0.15.2->inference)
#   Downloading pyvips-2.2.3.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rf-clip==1.1 (from inference-exp>=0.15.2->inference)
#   Downloading rf_clip-1.1-py3-none-any.whl.metadata (280 bytes)
# Collecting python-doctr<=0.11.0,>=0.10.0 (from python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading python_doctr-0.11.0-py3-none-any.whl.metadata (33 kB)
# Collecting rich<15.0.0,>=13.0.0 (from inference)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting segmentation-models-pytorch<1.0.0,>=0.5.0 (from inference-exp>=0.15.2->inference)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting ftfy (from rf-clip==1.1->inference-exp>=0.15.2->inference)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from rf-clip==1.1->inference-exp>=0.15.2->inference) (2024.11.6)
# Collecting coloredlogs (from onnxruntime<1.22.0,>=1.15.1->inference)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (1.13.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.3->inference) (2025.2)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.4.2)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from pydot~=2.0.0->inference) (3.2.5)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->inference) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=13.0.0->inference) (4.0.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (1.16.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (0.4)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.27->inference) (3.10.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.27->inference) (0.7.1)
# Collecting requests-file>=1.4 (from tldextract~=5.1.2->inference)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<0.23.0,>=0.19.0->inference) (0.36.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from twilio~=9.3.7->inference) (2.10.1)
# Collecting aiohttp-retry==2.8.3 (from twilio~=9.3.7->inference)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<=0.16.0,>=0.9.0->inference) (1.5.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.0.0->inference-exp>=0.15.2->inference) (0.6.2)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->inference)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->inference)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=44.0.0->aiortc>=1.9.0->inference) (2.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<0.23.0,>=0.19.0->inference) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<0.23.0,>=0.19.0->inference) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->inference) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision>=0.27->inference) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision>=0.27->inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision>=0.27->inference) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision>=0.27->inference) (1.4.9)
# Collecting docopt>=0.6.2 (from num2words~=0.5.14->inference-exp>=0.15.2->inference)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->asyncua~=1.1.5->inference) (1.17.0)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference) (3.15.1)
# Collecting pypdfium2<5.0.0,>=4.11.0 (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.6 MB/s eta 0:00:00
# Collecting pyclipper<2.0.0,>=1.2.0 (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 65.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting anyascii>=0.3.2 (from python-doctr<=0.11.0,>=0.10.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting onnx<3.0.0,>=1.12.0 (from python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference)
#   Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<1.22.0,>=1.15.1->inference) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<=3.10.11,>=3.9.0->inference) (0.4.1)
# Collecting isodate>=0.5.4 (from zeep<5.0.0,>=4.2.1->zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from zeep<5.0.0,>=4.2.1->zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference) (5.4.0)
# Requirement already satisfied: platformdirs>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from zeep<5.0.0,>=4.2.1->zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference) (4.5.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<1.22.0,>=1.15.1->inference)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->inference) (2.23)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch]<=0.11.0,>=0.10.0->inference-exp>=0.15.2->inference) (0.5.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->rf-clip==1.1->inference-exp>=0.15.2->inference) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->inference-exp>=0.15.2->inference) (3.0.3)
# Downloading inference-0.62.0-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 69.6 MB/s eta 0:00:00
# Downloading onvif_zeep_async-2.0.0-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.1/190.1 kB 23.3 MB/s eta 0:00:00
# Downloading pylogix-1.0.5-py2.py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.6 MB/s eta 0:00:00
# Downloading aiohttp-3.10.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.8 MB/s eta 0:00:00
# Downloading aiortc-1.14.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 11.9 MB/s eta 0:00:00
# Downloading anthropic-0.49.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 30.4 MB/s eta 0:00:00
# Downloading apscheduler-3.11.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 8.2 MB/s eta 0:00:00
# Downloading asyncua-1.1.8-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 79.4 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.60-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 17.9 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 13.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 15.9 MB/s eta 0:00:00
# Downloading fastapi-0.115.14-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.5/95.5 kB 12.0 MB/s eta 0:00:00
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading inference_exp-0.16.3-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.3/304.3 kB 34.7 MB/s eta 0:00:00
# Downloading rf_clip-1.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 55.4 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.575.51-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 5.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 78.0 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 11.1 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 13.4 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.8 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 98.5 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl (18 kB)
# Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 31.5 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading pymodbus-3.8.3-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.7/160.7 kB 20.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading qrcode-8.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.9 MB/s eta 0:00:00
# Downloading redis-5.0.8-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.6/255.6 kB 32.7 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 29.9 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 85.0 MB/s eta 0:00:00
# Downloading simple_pid-2.0.1-py3-none-any.whl (7.2 kB)
# Downloading slack_sdk-3.33.5-py2.py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.3/292.3 kB 34.6 MB/s eta 0:00:00
# Downloading structlog-24.4.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 9.2 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 13.7 MB/s eta 0:00:00
# Downloading twilio-9.3.8-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 98.0 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 5.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading zxing_cpp-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 kB 71.8 MB/s eta 0:00:00
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 23.8 MB/s eta 0:00:00
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 12.6 MB/s eta 0:00:00
# Downloading botocore-1.35.99-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 94.2 MB/s eta 0:00:00
# Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 141.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 6.1 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 20.9 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-1.0.0-cp310-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 56.8 MB/s eta 0:00:00
# Downloading pyopenssl-25.3.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 7.5 MB/s eta 0:00:00
# Downloading python_doctr-0.11.0-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.1/304.1 kB 33.7 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 11.1 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 21.0 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 9.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading zeep-4.3.2-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 13.3 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 38.2 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 38.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.9 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 71.8 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 73.0 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 96.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.8 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
# Building wheels for collected packages: paho-mqtt, pybase64, pyvips, docopt, langdetect
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62116 sha256=d49d0a5bffbe1f22670b5bdf752d476ad4a9f0eccc381c7af792769d2ccb7e12
#   Stored in directory: /root/.cache/pip/wheels/23/d5/af/1f3cbcc350dec9d8e95040f388e0163d132eff0c9a453db659
#   Building wheel for pybase64 (pyproject.toml) ... done
#   Created wheel for pybase64: filename=pybase64-1.0.2-cp312-cp312-linux_x86_64.whl size=147464 sha256=ec2ac1d9dee0f6efbfa88e310455787c6cd444d883d200c774b06f8d8b69bfb7
#   Stored in directory: /root/.cache/pip/wheels/ba/62/aa/895a2495c012f960e827ad0930f338c7aea4708b677c44124a
#   Building wheel for pyvips (setup.py) ... done
#   Created wheel for pyvips: filename=pyvips-2.2.3-py2.py3-none-any.whl size=54850 sha256=61ac2ca3932e9010cf4789e79a875d6c526b5824bad667904153daa32ee33f1e
#   Stored in directory: /root/.cache/pip/wheels/f8/70/6e/576099b6eaf9bee1073262571b24d9a850b1d0f3451434506b
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=99d4cb95a67104654a7da87daef41ab1aa8bf8df6f281d32f454948d7eac869d
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=c916c9c8326c4e746a5c9dbf5f50b945c268b7457a055c42fb35022d3052b492
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built paho-mqtt pybase64 pyvips docopt langdetect
# Installing collected packages: pylogix, pyclipper, paho-mqtt, nvidia-ml-py, ifaddr, docopt, zxing-cpp, typing_extensions, structlog, slack-sdk, simple-pid, shapely, redis, rapidfuzz, qrcode, python-dotenv, pypdfium2, pymodbus, pydot, pybase64, psutil, packaging, opencv-python, opencv-contrib-python, num2words, mypy-extensions, langdetect, jmespath, isodate, humanfriendly, ftfy, filelock, dnspython, click, backoff, av, APScheduler, anyascii, typing-inspect, rich, requests-file, pyvips, pylibsrtp, pyee, pandas, onnx, marshmallow, docker, cryptography, coloredlogs, botocore, aiosqlite, aioice, zeep, typer, tldextract, starlette, s3transfer, python-doctr, pyopenssl, onnxruntime, dataclasses-json, aiohttp, pydantic-settings, fastapi, boto3, bitsandbytes, asyncua, anthropic, aiortc, aiohttp-retry, twilio, rf-clip, prometheus-fastapi-instrumentator, onvif-zeep-async, segmentation-models-pytorch, inference-exp, inference
#   Attempting uninstall: nvidia-ml-py
#     Found existing installation: nvidia-ml-py 13.580.82
#     Uninstalling nvidia-ml-py-13.580.82:
#       Successfully uninstalled nvidia-ml-py-13.580.82
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.2
#     Uninstalling shapely-2.1.2:
#       Successfully uninstalled shapely-2.1.2
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.1
#     Uninstalling python-dotenv-1.2.1:
#       Successfully uninstalled python-dotenv-1.2.1
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.4
#     Uninstalling pydot-3.0.4:
#       Successfully uninstalled pydot-3.0.4
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.12.0.88
#     Uninstalling opencv-contrib-python-4.12.0.88:
#       Successfully uninstalled opencv-contrib-python-4.12.0.88
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.20.0
#     Uninstalling typer-0.20.0:
#       Successfully uninstalled typer-0.20.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.49.3
#     Uninstalling starlette-0.49.3:
#       Successfully uninstalled starlette-0.49.3
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.2
#     Uninstalling aiohttp-3.13.2:
#       Successfully uninstalled aiohttp-3.13.2
#   Attempting uninstall: pydantic-settings
#     Found existing installation: pydantic-settings 2.12.0
#     Uninstalling pydantic-settings-2.12.0:
#       Successfully uninstalled pydantic-settings-2.12.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.121.1
#     Uninstalling fastapi-0.121.1:
#       Successfully uninstalled fastapi-0.121.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# bigframes 2.28.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# typeguard 4.4.4 requires typing_extensions>=4.14.0, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed APScheduler-3.11.1 aiohttp-3.10.11 aiohttp-retry-2.8.3 aioice-0.10.1 aiortc-1.14.0 aiosqlite-0.21.0 anthropic-0.49.0 anyascii-0.3.3 asyncua-1.1.8 av-16.0.1 backoff-2.2.1 bitsandbytes-0.47.0 boto3-1.35.60 botocore-1.35.99 click-8.1.8 coloredlogs-15.0.1 cryptography-46.0.3 dataclasses-json-0.6.7 dnspython-2.8.0 docker-7.1.0 docopt-0.6.2 fastapi-0.115.14 filelock-3.17.0 ftfy-6.3.1 humanfriendly-10.0 ifaddr-0.2.0 inference-0.62.0 inference-exp-0.16.3 isodate-0.7.2 jmespath-1.0.1 langdetect-1.0.9 marshmallow-3.26.1 mypy-extensions-1.1.0 num2words-0.5.14 nvidia-ml-py-12.575.51 onnx-1.19.1 onnxruntime-1.21.1 onvif-zeep-async-2.0.0 opencv-contrib-python-4.10.0.84 opencv-python-4.10.0.84 packaging-24.2 paho-mqtt-1.6.1 pandas-2.3.3 prometheus-fastapi-instrumentator-6.0.0 psutil-7.1.3 pybase64-1.0.2 pyclipper-1.3.0.post6 pydantic-settings-2.7.1 pydot-2.0.0 pyee-13.0.0 pylibsrtp-1.0.0 pylogix-1.0.5 pymodbus-3.8.3 pyopenssl-25.3.0 pypdfium2-4.30.0 python-doctr-0.11.0 python-dotenv-1.0.1 pyvips-2.2.3 qrcode-8.0 rapidfuzz-3.14.3 redis-5.0.8 requests-file-3.0.1 rf-clip-1.1 rich-14.2.0 s3transfer-0.10.4 segmentation-models-pytorch-0.5.0 shapely-2.0.7 simple-pid-2.0.1 slack-sdk-3.33.5 starlette-0.46.2 structlog-24.4.0 tldextract-5.1.3 twilio-9.3.8 typer-0.16.0 typing-inspect-0.9.0 typing_extensions-4.12.2 zeep-4.3.2 zxing-cpp-2.2.0

# %%
import os, random, cv2
import supervision as sv
import IPython
import inference

model_id = project.id.split("/")[1] + "/" + dataset.version
model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))

# Location of test set images
test_set_loc = dataset.location + "/test/images/"
test_images = os.listdir(test_set_loc)

# Run inference on 4 random test images, or fewer if fewer images are available
for img_name in random.sample(test_images, min(4, len(test_images))):
    print("Running inference on " + img_name)

    # Load image
    image = cv2.imread(os.path.join(test_set_loc, img_name))

    # Perform inference
    results = model.infer(image, confidence=0.4, overlap=30)[0]
    detections = sv.Detections.from_inference(results)

    # Annotate boxes and labels
    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()
    annotated_image = box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    _, ret = cv2.imencode('.jpg', annotated_image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)
# Out:
# Your `inference` configuration does not support PaliGemma model. Use pip install 'inference[transformers]' to install missing requirements.To suppress this warning, set PALIGEMMA_ENABLED to False.

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
